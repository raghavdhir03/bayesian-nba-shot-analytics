# %%
from nba_api.stats.endpoints import shotchartdetail
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Rectangle, Arc

# Someone already built the court drawing function
# Just use their code + add your Bayesian colors

# %%
df['zone'].unique()
# Out:
# array(['Above the Break 3', 'In The Paint (Non-RA)', 'Left Corner 3',
#        'Mid-Range', 'Restricted Area', 'Right Corner 3', 'Backcourt'],
#       dtype=object)

# %%
df = pd.read_parquet('bayesian_posteriors_2023_24.parquet')

# %%
df.head(10)
# Out:
#    player_id   player_name position                   zone  attempts  makes  \
# 0       2544  LeBron James  Forward      Above the Break 3       318    129
# 1       2544  LeBron James  Forward  In The Paint (Non-RA)       194     81
# 2       2544  LeBron James  Forward          Left Corner 3        21      7
# 3       2544  LeBron James  Forward              Mid-Range       165     54
# 4       2544  LeBron James  Forward        Restricted Area       547    401
# 5       2544  LeBron James  Forward         Right Corner 3        23     13
# 6     101108    Chris Paul    Guard      Above the Break 3       168     69
# 7     101108    Chris Paul    Guard  In The Paint (Non-RA)        85     45
# 8     101108    Chris Paul    Guard          Left Corner 3        22      5
# 9     101108    Chris Paul    Guard              Mid-Range       159     71
#
#    raw_fg_pct  prior_fg_pct  posterior_mean  ci_lower  ci_upper  ci_width  \
# ...
